# %%
import pandas as pd

# %%
indata = pd.read_csv("../dataset/kopo_customerdata.csv")
indata
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# ...

# %%
indata.dtypes # CUSTOMERCODE : int
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
# 컬럼의 타입을 변경시키는 코드다 (전체 컬럼을 float로 바꿔보자!)
indata.CUSTOMERCODE = indata.CUSTOMERCODE.astype(float)

# %%
indata.dtypes # COUSTOMERCODE : float로 변경
# Out:
# CUSTOMERCODE     float64
# STATENAME         object
# ST                 int64
# GENDER            object
# DOB                int64
# GENDER1            int64
# EMAIL              int64
# FEST_CNT           int64
# TOTAL_AMOUNT       int64
# AC_AMOUNT          int64
# AV_AMOUNT          int64
# HA_AMOUNT          int64
# EMI_CE_AMOUNT      int64
# IS_HIGHEND         int64
# CNT_VIST           int64
# GAP_VISIT          int64
# dtype: object

# %%
indata.columns
# Out:
# Index(['CUSTOMERCODE', 'STATENAME', 'ST', 'GENDER', 'DOB', 'GENDER1', 'EMAIL',
#        'FEST_CNT', 'TOTAL_AMOUNT', 'AC_AMOUNT', 'AV_AMOUNT', 'HA_AMOUNT',
#        'EMI_CE_AMOUNT', 'IS_HIGHEND', 'CNT_VIST', 'GAP_VISIT'],
#       dtype='object')

# %%
columnList = list (indata.columns)

# %%
for i in range(0, len(columnList)):
    try:
        indata[columnList[i]] = indata[columnList[i]].astype(float)
    except :
        print(columnList[i])
# Out:
# STATENAME
# GENDER

# %%
indata.dtypes # 문자열은 정수로 바뀌지 않기 때문에 STATENAME, GENDER가 출력되었다.
# Out:
# CUSTOMERCODE     float64
# STATENAME         object
# ST               float64
# GENDER            object
# DOB              float64
# GENDER1          float64
# EMAIL            float64
# FEST_CNT         float64
# TOTAL_AMOUNT     float64
# AC_AMOUNT        float64
# AV_AMOUNT        float64
# HA_AMOUNT        float64
# EMI_CE_AMOUNT    float64
# IS_HIGHEND       float64
# CNT_VIST         float64
# GAP_VISIT        float64
# dtype: object

# %%
indata = pd.read_csv("../dataset/kopo_customerdata.csv")
indata.head(2)
# Out:
#    CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2   Male    0        1      1         0
# 1       1190338    State2   2   Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0

# %%
indata = pd.read_csv("../dataset/kopo_customerdata.csv")
indata
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# ...

# %%
indata.dtypes # CUSTOMERCODE : int
# Out:
# CUSTOMERCODE      int64
# STATENAME        object
# ST                int64
# GENDER           object
# DOB               int64
# GENDER1           int64
# EMAIL             int64
# FEST_CNT          int64
# TOTAL_AMOUNT      int64
# AC_AMOUNT         int64
# AV_AMOUNT         int64
# HA_AMOUNT         int64
# EMI_CE_AMOUNT     int64
# IS_HIGHEND        int64
# CNT_VIST          int64
# GAP_VISIT         int64
# dtype: object

# %%
for i in range(0, len(columnList)): 
    targetColumn = columnList[i]
    print(targetColumn) # 중간에 실행중인 targetColumn
    indata[columnList[i]] = indata[columnList[i]].astype(float)
    # CUSTOMERCODE, STATENAME 출력
    
# STATENAME을 기점으로 오류가 나는 것을 확인 할 수 있다.
# Out:
# CUSTOMERCODE
# STATENAME
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10592\1909709865.py in <module>
#       2     targetColumn = columnList[i]
#       3     print(targetColumn) # 중간에 실행중인 targetColumn
# ----> 4     indata[columnList[i]] = indata[columnList[i]].astype(float)
#       5     # CUSTOMERCODE, STATENAME 출력
#       6
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
# ...

# %%
indata = pd.read_csv("../dataset/kopo_customerdata.csv")
indata 
# 불러온 데이터의 해당 컬럼명을 다시 한번 확인해본다.
# CUSTOMERCODE, STATENAME는 문자열이라서 실수로 변환이 불가한 것을 확인했다.
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# ...

# %%
# 교수님 풀이
for i in range(0, len(columnList)): #
    targetColumn = columnList[i]
    print(targetColumn)
    # 타입 변경 (기존타입 -> float)
    try :
        indata[targetColumn] = indata[targetColumn].astype(float)
    # 타입을 못바꾸는 경우 (오류메시지 출력) * 에러는 발생되지 않음
    except Exception as e :
        print(e)
# Out:
# CUSTOMERCODE
# STATENAME
# could not convert string to float: 'State2'
# ST
# GENDER
# could not convert string to float: 'Male'
# DOB
# GENDER1
# EMAIL
# FEST_CNT
# TOTAL_AMOUNT
# AC_AMOUNT
# AV_AMOUNT
# HA_AMOUNT
# EMI_CE_AMOUNT
# IS_HIGHEND
# CNT_VIST
# GAP_VISIT

# %%
pd.read_csv("../dataset/kopo_customerdata.csv")
# Out:
#         CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0            1503989    State2   2    Male    0        1      1         0
# 1            1190338    State2   2    Male    0        1      0         1
# 2            1424715    State2   2  Female    0        2      0         0
# 3            2483305    State2   2    Male    0        1      0         1
# 4            1178802    State2   2    Male    0        1      0         1
# ...              ...       ...  ..     ...  ...      ...    ...       ...
# 299995        465757    State1   1    Male    0        1      0         0
# 299996       1890264    State1   1    Male    0        1      0         1
# 299997       1857537    State1   1  Female    0        2      0         0
# 299998       2209324    State1   1    Male    0        1      0         1
# 299999       1875146    State1   1    Male    0        1      0         1
#
#         TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  \
# ...

# %%
# continue 활용한 풀이
for i in range(0, len(columnList)): #
    targetColumn = columnList[i]
    print(targetColumn)
    # 타입 변경 (기존타입 -> float)
    if( type(indata.loc[0, columnList[i] ]) == str) : 
        print("{}컬럼은 문자열이기 때문에 continue탐".format(targetColumn))
        continue
    indata[targetColumn] = indata[targetColumn].astype(float)
# Out:
# CUSTOMERCODE
# STATENAME
# STATENAME컬럼은 문자열이기 때문에 continue탐
# ST
# GENDER
# GENDER컬럼은 문자열이기 때문에 continue탐
# DOB
# GENDER1
# EMAIL
# FEST_CNT
# TOTAL_AMOUNT
# AC_AMOUNT
# AV_AMOUNT
# HA_AMOUNT
# EMI_CE_AMOUNT
# IS_HIGHEND
# CNT_VIST
# GAP_VISIT
